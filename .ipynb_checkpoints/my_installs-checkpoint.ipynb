# %%
# !pip install git+ssh://git@github.com/smarshak33/my-installs.git
# Out:
# ...
#   Cloning ssh://****@github.com/smarshak33/my-installs.git to /private/var/folders/vv/tf9r_62j1k75w_b3m6khrjgc0000gn/T/pip-req-build-owil4w9a
#   Running command git clone --filter=blob:none --quiet 'ssh://****@github.com/smarshak33/my-installs.git' /private/var/folders/vv/tf9r_62j1k75w_b3m6khrjgc0000gn/T/pip-req-build-owil4w9a
#   Resolved ssh://****@github.com/smarshak33/my-installs.git to commit dabec052a25a70da02633d9717a562d665582ecb
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for my-installs: filename=my_installs-0.1.0-py3-none-any.whl size=1453 sha256=8d5fd02d93cd9d7eb626dbf3d75ab081343caf7ea5e513d0b52eeaa7d91fb270
#   Stored in directory: /private/var/folders/vv/tf9r_62j1k75w_b3m6khrjgc0000gn/T/pip-ephem-wheel-cache-nvchc2w0/wheels/d8/33/ea/5abb4419232d9b48d174b469c65217af719056c4a703f18c4e
# Successfully built my-installs
# ...

# %%
from my_installs import addNumbers
addNumbers(10, 20)
# Out:
# 30
